# %% [markdown]
# <a href="https://colab.research.google.com/github/AfraazUlHaque/DRONE-DRISHTI/blob/main/ZENORA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0ed6bd8-7970-4192-a150-f8b4cee951af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0ed6bd8-7970-4192-a150-f8b4cee951af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q goddard_mvp.zip -d /content/

# %%
# !find mnt/data/goddard_mvp/frames -type f | wc -l
# Out:
# 125

# %%
# !apt-get update -qq
# !apt-get install -y colmap
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core gsettings-desktop-schemas libamd2 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libcamd2 libccolamd2 libceres2
#   libcholmod3 libcolamd2 libcxsparse3 libdouble-conversion3 libevdev2
#   libfreeimage3 libgflags2.2 libglew2.2 libgoogle-glog0v5 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libilmbase25 libinput-bin
#   libinput10 libjxr0 libmd4c0 libmetis5 libmtdev1 libopenexr25 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libraw20
#   librsvg2-common libspqr2 libsuitesparseconfig5 libwacom-bin libwacom-common
# ...

# %%
# !colmap -h | head
# Out:
# COLMAP 3.7 -- Structure-from-Motion and Multi-View Stereo
#               (Commit Unknown on Unknown without CUDA)
#
# Usage:
#   colmap [command] [options]
#
# Documentation:
#   https://colmap.github.io/
#
# Example usage:

# %%
BASE = "/content/mnt/data/goddard_mvp"

# !mkdir -p {BASE}/colmap

# %%
# %env QT_QPA_PLATFORM=offscreen
# Out:
# env: QT_QPA_PLATFORM=offscreen

# %%
# !QT_QPA_PLATFORM=offscreen colmap feature_extractor \
    --database_path {BASE}/colmap/database.db \
    --image_path {BASE}/frames \
    --ImageReader.single_camera 1 \
    --ImageReader.camera_model OPENCV \
    --SiftExtraction.use_gpu 0
# Out:
# WARNING: Your current options use the maximum number of threads on the machine to extract features. Exracting SIFT features on the CPU can consume a lot of RAM per thread for large images. Consider reducing the maximum image size and/or the first octave or manually limit the number of extraction threads. Ignore this warning, if your machine has sufficient memory for the current settings.
#
# ...
# Feature extraction
# ...
#
# Processed file [1/125]
#   Name:            frame_00000.jpg
#   Dimensions:      1920 x 1080
#   Camera:          #1 - OPENCV
#   Focal Length:    2304.00px
#   Features:        11760
# Processed file [2/125]
#   Name:            frame_00010.jpg
#   Dimensions:      1920 x 1080
#   Camera:          #1 - OPENCV
#   Focal Length:    2304.00px
#   Features:        11930
# Processed file [3/125]
#   Name:            frame_00020.jpg
#   Dimensions:      1920 x 1080
#   Camera:          #1 - OPENCV
#   Focal Length:    2304.00px
#   Features:        11973
# ...

# %%
# !QT_QPA_PLATFORM=offscreen colmap sequential_matcher \
    --database_path {BASE}/colmap/database.db \
    --SequentialMatching.overlap 10 \
    --SiftMatching.use_gpu 0
# Out:
# ...
# Sequential feature matching
# ...
#
# Matching image [1/125] in 19.444s
# Matching image [2/125] in 20.834s
# Matching image [3/125] in 19.686s
# Matching image [4/125] in 21.201s
# Matching image [5/125] in 19.429s
# Matching image [6/125] in 20.983s
# Matching image [7/125] in 19.517s
# Matching image [8/125] in 20.482s
# Matching image [9/125] in 19.116s
# Matching image [10/125] in 19.630s
# Matching image [11/125] in 20.039s
# Matching image [12/125] in 19.096s
# Matching image [13/125] in 20.763s
# Matching image [14/125] in 18.979s
# Matching image [15/125] in 20.535s
# Matching image [16/125] in 19.839s
# Matching image [17/125] in 20.731s
# Matching image [18/125] in 19.519s
# Matching image [19/125] in 26.617s
# Matching image [20/125] in 27.234s
# Matching image [21/125] in 28.082s
# Matching image [22/125] in 25.720s
# Matching image [23/125] in 25.762s
# Matching image [24/125] in 25.830s
# Matching image [25/125] in 24.703s
# Matching image [26/125] in 25.377s
# ...

# %%
# !QT_QPA_PLATFORM=offscreen colmap mapper \
    --database_path {BASE}/colmap/database.db \
    --image_path {BASE}/frames \
    --output_path {BASE}/sparse

# %%
# !find {BASE}/sparse -maxdepth 2 -type f
